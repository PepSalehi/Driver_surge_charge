# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt; 
import matplotlib.animation as animation
# %matplotlib inline 
from matplotlib import  rc
from IPython.display import HTML, Image

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %%
TWOPI = 2 * np.pi

fig, ax = plt.subplots()

t = np.arange(0.0, TWOPI, 0.001)
s = np.sin(t)
l = plt.plot(t, s)

ax = plt.axis([0, TWOPI, -1, 1])

redDot, = plt.plot([0], [np.sin(0)], 'ro')


def animate(i):
    redDot.set_data(i, np.sin(i))
    return redDot,


# create animation using the animate() function
myAnimation = animation.FuncAnimation(fig, animate, frames=np.arange(0.0, TWOPI, 0.1), \
                                      interval=10, blit=True, repeat=True)

plt.show()

# %%
fig, ax = plt.subplots()
xdata, ydata = [], []
ln, = plt.plot([], [], 'ro')


# Set up formatting for the movie files
Writer = animation.writers['ffmpeg']
writer = Writer(fps=15, metadata=dict(artist='Me'), bitrate=1800)


def init():
    ax.set_xlim(0, 2*np.pi)
    ax.set_ylim(-1, 1)
    return ln,

def update(frame):
    xdata.append(frame)
    ydata.append(np.sin(frame))
    ln.set_data(xdata, ydata)
    return ln,

ani = animation.FuncAnimation(fig, update, frames=np.linspace(0, 2*np.pi, 128),
                    init_func=init, blit=True)
ani.save('double_pendulum.mp4', writer=writer)
plt.show()

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([], [], lw=2)

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# %%
# animation function. This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)

# %%
# call the animator. blit=True means only re-draw the parts that 
# have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# !brew install imagemagick
# Out:
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 3 taps (homebrew/core, homebrew/cask and dlr-ts/sumo).
# ==> New Formulae
# asuka                      gdbgui                     openfast
# autodiff                   ghc@8.8                    openstackclient
# bootloadhid                ghz                        pfetch
# cbmc                       git-bug                    quill
# chezmoi                    gmailctl                   rbtools
# claws-mail                 gocloc                     rcm
# clip                       guile@2                    redo
# code-server                hcxtools                   reorder-python-imports
# cqlkit                     hdf5-mpi                   rtorrent
# cucumber-ruby              jc                         semgrep
# detach                     jolie                      sollya
# dlr-ts/sumo/sumo@1.5.0     kamel                      spotify-tui
# dmagnetic                  kde-extra-cmake-modules    spotifyd
# duktape                    kumactl                    tanka
# earthly                    lc0                        trailscraper
# erlang@22                  leakcanary-shark           trimage
# eva                        libcpuid                   uutils-coreutils
# fargatecli                 libolm                     vlmcsd
# fcct                       libpqxx@6                  volta
# field3d                    libtorrent-rakshasa        xxh
# flarectl                   lizard-analyzer            zenith
# fplll                      odin
# gau                        oha
# ==> Updated Formulae
# boost ✔                                  librsync
# cmake ✔                                  libsass
# dlr-ts/sumo/sumo ✔                       libserdes
# ffmpeg ✔                                 libspectre
# fish ✔                                   libspiro
# gdk-pixbuf ✔                             libtensorflow
# gettext ✔                                libtensorflow@1
# git ✔                                    libtorch
# glib ✔                                   libtorrent-rasterbar
# gnutls ✔                                 libuv
# gobject-introspection ✔                  libvirt
# graphviz ✔                               libvisio
# gsettings-desktop-schemas ✔              libwbxml
# gtk+3 ✔                                  libwebsockets
# harfbuzz ✔                               libxmlsec1
# highlight ✔                              libyaml
# icu4c ✔                                  libzt
# ilmbase ✔                                lilv
# imagemagick ✔                            liquibase
# libepoxy ✔                               liquidctl
# libffi ✔                                 liquigraph
# librsvg ✔                                literate-git
# netpbm ✔                                 livestreamer
# nettle ✔                                 llnode
# numpy ✔                                  llvm
# openexr ✔                                llvm@6
# openssl@1.1 ✔                            llvm@7
# p11-kit ✔                                llvm@8
# pcre2 ✔                                  llvm@9
# pixman ✔                                 lmdb
# proj ✔                                   lmod
# pygobject3 ✔                             logstash
# shared-mime-info ✔                       logtalk
# tmux ✔                                   luaradio
# unbound ✔                                lv
# x264 ✔                                   lv2
# youtube-dl ✔                             lxc
# abcl                                     macvim
# abcmidi                                  makeself
# abook                                    mame
# abseil                                   mapnik
# ace                                      mapserver
# acpica                                   mariadb
# adios2                                   mariadb@10.2
# adplug                                   mariadb@10.3
# algol68g                                 mas
# aliyun-cli                               maven-completion
# allure                                   mavsdk
# alot                                     maxwell
# ammonite-repl                            mdcat
# amqp-cpp                                 mdk
# angular-cli                              mdv
# anime-downloader                         mednafen
# ansible                                  megatools
# ansible@2.8                              meilisearch
# ant                                      memcached
# ant@1.9                                  mercurial
# apache-arrow                             mercury
# apache-arrow-glib                        mesa
# apache-flink                             meson
# apollo-cli                               meson-internal
# appium                                   metabase
# arangodb                                 mftrace
# archivemount                             mg
# armadillo                                mgba
# artifactory                              micro
# asciidoctor                              micronaut
# asciidoctorj                             micropython
# asio                                     mikutter
# ask-cli                                  mill
# astrometry-net                           minidlna
# atlantis                                 minikube
# audacious                                minimal-racket
# autogen                                  minio
# autopep8                                 minio-mc
# aws-cdk                                  mitie
# aws-elasticbeanstalk                     mk-configure
# aws-google-auth                          mkdocs
# aws-sdk-cpp                              mkl-dnn
# awscli                                   mkvtomp4
# awscli@1                                 mkvtoolnix
# azcopy                                   mlpack
# azure-cli                                mm-common
# azure-storage-cpp                        mmctl
# b3sum                                    moarvm
# babel                                    mockolo
# babeld                                   modman
# babl                                     molecule
# balena-cli                               molten-vk
# ballerina                                monero
# bandwhich                                mongo-orchestration
# baobab                                   mono
# bareos-client                            mono-libgdiplus
# bartycrouch                              monolith
# basex                                    mosh
# bash                                     movgrab
# bat                                      mpd
# batik                                    mpop
# bats-core                                mps-youtube
# bazel                                    mpv
# bazelisk                                 msmtp
# bcoin                                    mu
# bde                                      mujs
# benthos                                  mupdf
# bento4                                   mupdf-tools
# bgpdump                                  mutt
# bibtexconv                               mvnvm
# binaryen                                 mvtools
# bind                                     mycli
# bindfs                                   mypy
# bison                                    mysql
# bitrise                                  mysql-client
# blackbox                                 mysql-client@5.7
# blitz                                    mysql-connector-c++
# bluepill                                 mysql-search-replace
# bluetoothconnector                       nagios
# bmake                                    nanopb-generator
# bochs                                    nativefier
# borgmatic                                nats-server
# buildifier                               navi
# buildkit                                 ncmpc
# bullet                                   ncmpcpp
# bundletool                               needle
# c-ares                                   nef
# caddy                                    neomutt
# caf                                      neon
# caffe                                    nestopia-ue
# calabash                                 netdata
# calicoctl                                netlify-cli
# capnp                                    newman
# capstone                                 newrelic-cli
# cargo-c                                  ngt
# cargo-completion                         nickle
# cartridge-cli                            nicovideo-dl
# cassandra-cpp-driver                     nift
# catch2                                   nlopt
# cattle                                   node
# ccfits                                   node-build
# ccls                                     node-sass
# cdk8s                                    node@10
# certbot                                  node@12
# cfengine                                 nomad
# cfitsio                                  notifiers
# cfn-lint                                 notmuch
# cfr-decompiler                           now-cli
# cglm                                     nqp
# cgns                                     nrpe
# cgoban                                   nss
# chadwick                                 nuget
# chakra                                   nushell
# chamber                                  nut
# charm-tools                              nuttcp
# cheat                                    nyx
# checkbashisms                            oauth2_proxy
# checkstyle                               oclgrind
# chordii                                  ocrmypdf
# chromaprint                              octant
# chronograf                               okteto
# chuck                                    oniguruma
# circleci                                 onscripter
# citus                                    opa
# ckan                                     opam
# clamav                                   open-babel
# clang-format                             open-completion
# clib                                     open-image-denoise
# clingo                                   open-mesh
# cloc                                     open-zwave
# clojure-lsp                              openapi-generator
# clojurescript                            opencc
# closure-compiler                         openconnect
# clozure-cl                               opencv
# clp                                      opencv@2
# cmark                                    opencv@3
# cmark-gfm                                openfortivpn
# codespell                                openh264
# colordiff                                openimageio
# commandbox                               openldap
# composer                                 openrct2
# conan                                    opensaml
# concurrencykit                           openvdb
# conserver                                operator-sdk
# console_bridge                           orc-tools
# consul                                   osc
# consul-template                          osm2pgrouting
# contentful-cli                           osmium-tool
# convox                                   osmosis
# cookiecutter                             osquery
# corral                                   otf2
# cosi                                     oxipng
# coturn                                   pachi
# couchdb                                  packer
# cpl                                      paket
# cpp-gsl                                  parallel
# cppcheck                                 pari
# cpprestsdk                               passpie
# creduce                                  pastebinit
# cromwell                                 pazpar2
# csvq                                     pdfcrack
# ctemplate                                pdfpc
# ctl                                      pdfsandwich
# cups                                     pdftk-java
# curaengine                               pdftoipe
# curl                                     pegtl
# curl-openssl                             percona-toolkit
# cypher-shell                             peru
# cython                                   petsc
# dafny                                    petsc-complex
# daq                                      pgbouncer
# darcs                                    pgrouting
# dartsim                                  phoronix-test-suite
# dasm                                     php
# datamash                                 php-code-sniffer
# datetime-fortran                         php@7.2
# dav1d                                    php@7.3
# davix                                    phpstan
# davmail                                  phpunit
# dbmate                                   pianobar
# deno                                     picard-tools
# deployer                                 picat
# detekt                                   pidgin
# detox                                    pike
# devspace                                 pinboard-notes-backup
# dfmt                                     pipx
# dhall                                    pius
# dhall-bash                               planck
# dhall-json                               plantuml
# dhall-lsp-server                         platformio
# dhall-yaml                               pmd
# diamond                                  pngpaste
# diff-pdf                                 pnpm
# diff-so-fancy                            poetry
# diffoscope                               polynote
# direnv                                   ponyc
# dita-ot                                  ponysay
# django-completion                        poppler
# dmd                                      posh
# dnsdist                                  postgresql
# dnstwist                                 postgresql@10
# docfx                                    postgresql@11
# docker                                   postgresql@9.5
# docker-completion                        postgresql@9.6
# doctl                                    postgrest
# docutils                                 powerline-go
# dolt                                     pre-commit
# dosbox-x                                 prestosql
# dovecot                                  prettier
# doxygen                                  procs
# drafter                                  prometheus
# dscanner                                 proteinortho
# dub                                      protobuf
# duck                                     protobuf-c
# dune                                     protoc-gen-go
# dungeon                                  protoc-gen-grpc-web
# duo_unix                                 prototool
# duplicity                                proxytunnel
# dvc                                      pspg
# dwdiff                                   pueue
# dxpy                                     pulumi
# e2fsprogs                                puzzles
# e2tools                                  pwntools
# easy-tag                                 pycodestyle
# easyrpg-player                           pyinstaller
# ecl                                      pylint
# efl                                      pympress
# ejabberd                                 pypy
# ejdb                                     pypy3
# elasticsearch                            pyside
# elixir                                   python-markdown
# embree                                   python-yq
# emscripten                               qalculate-gtk
# enet                                     qbs
# ensmallen                                qcachegrind
# entr                                     qcli
# envconsul                                qemu
# epic5                                    qmmp
# erlang                                   qpid-proton
# erlang@21                                qt
# eslint                                   quazip
# etcd                                     questdb
# ethereum                                 quickjs
# evince                                   qxmpp
# exif                                     r
# exploitdb                                rakudo
# ext2fuse                                 rakudo-star
# faas-cli                                 rancher-cli
# fastlane                                 rargs
# fasttext                                 ratfor
# faudio                                   rawtoaces
# fauna-shell                              rbspy
# fb-client                                rdesktop
# fd                                       rdfind
# fdroidserver                             rdiff-backup
# feedgnuplot                              rdup
# fetchmail                                re-flex
# ffmpeg2theora                            re2
# ffmpeg@2.8                               rebar3
# ffmpegthumbnailer                        recon-ng
# ffms2                                    redex
# ffsend                                   redis
# fibjs                                    redpen
# file-roller                              repo
# filebeat                                 restview
# findent                                  rex
# firebase-cli                             ripgrep
# flake8                                   ripgrep-all
# flow                                     rke
# fluent-bit                               robot-framework
# flyway                                   robotfindskitten
# fmt                                      rom-tools
# fn                                       root
# folly                                    roswell
# fontforge                                rswift
# fonttools                                rsyslog
# fop                                      ruby
# forcecli                                 ruby-build
# freeciv                                  rust
# freediameter                             s-nail
# freeipmi                                 s3fs
# freeling                                 s3ql
# freerdp                                  sagittarius-scheme
# freetds                                  salt
# frotz                                    sane-backends
# frpc                                     sbcl
# frps                                     scala
# frugal                                   scamper
# fs-uae                                   scrcpy
# fselect                                  sd
# funcoeszz                                seal
# fuseki                                   sec
# futhark                                  sentencepiece
# fwup                                     serd
# gatsby-cli                               serf
# gcab                                     serverless
# gcviewer                                 shadowenv
# gdal                                     shfmt
# gedit                                    shibboleth-sp
# gegl                                     shogun
# geogram                                  shyaml
# geoipupdate                              sile
# geoserver                                silk
# geph2                                    simgrid
# gerbil-scheme                            simple-scan
# gexiv2                                   singular
# gforth                                   siril
# gh                                       sispmctl
# ghc                                      skaffold
# ghex                                     skopeo
# gimme                                    sleuthkit
# git-absorb                               snakemake
# git-annex                                snapcraft
# git-cinnabar                             softhsm
# git-delta                                solarus
# git-gui                                  solr
# git-lfs                                  sonarqube
# git-plus                                 sonarqube-lts
# git-quick-stats                          sonobuoy
# git-series                               sourcedocs
# git-trim                                 sourcery
# gitfs                                    spades
# gitg                                     spdlog
# github-release                           sphinx-doc
# gitlab-gem                               spoof-mac
# gitlab-runner                            spotbugs
# gitleaks                                 sql-translator
# gitless                                  sqlcipher
# gitmoji                                  sqlmap
# gjs                                      squid
# glade                                    src
# gleam                                    ssh-audit
# glib-networking                          sslmate
# glib-openssl                             sslyze
# glm                                      starship
# glooctl                                  stella
# glslang                                  stellar-core
# gnome-recipes                            step
# gnu-chess                                stoken
# gnu-smalltalk                            stone-soup
# gnumeric                                 streamlink
# go                                       stress-ng
# go-jsonnet                               subliminal
# go@1.13                                  subversion
# goaccess                                 sundials
# godep                                    supervisor
# goffice                                  suricata
# golang-migrate                           swagger-codegen
# gom                                      swagger-codegen@2
# gomplate                                 swift
# googler                                  swift-protobuf
# goose                                    swiftformat
# gopass                                   syncthing
# goreleaser                               synfig
# gotop                                    sysbench
# gpgme                                    sysdig
# gr-osmosdr                               tarantool
# gradle                                   tarsnapper
# grafana                                  tass64
# grakn                                    tccutil
# graphene                                 tealdeer
# grc                                      tectonic
# gromacs                                  teensy_loader_cli
# groonga                                  tektoncd-cli
# groovy                                   telegraf
# groovysdk                                teleport
# grpc                                     template-glib
# grpcurl                                  tengo
# grsync                                   termius
# gsoap                                    termrec
# gspell                                   termtosvg
# gst-plugins-bad                          terraform
# gst-plugins-ugly                         terragrunt
# gtranslator                              testssl
# gucharmap                                texlab
# guile                                    texmath
# gwt                                      tflint
# hadolint                                 theharvester
# handbrake                                thors-serializer
# hapi-fhir-cli                            tika
# hashpump                                 tile38
# haskell-stack                            timewarrior
# haxe                                     timidity
# healpix                                  tintin
# heartbeat                                tmux-xpanes
# hebcal                                   tmuxinator
# helm                                     tmuxinator-completion
# helm@2                                   tokei
# helmfile                                 tomcat
# helmsman                                 tomcat-native
# help2man                                 tomcat@7
# hfstospell                               tomcat@8
# hive                                     topgrade
# hlint                                    tor
# homeassistant-cli                        tox
# homebank                                 traefik
# honcho                                   trafficserver
# hopenpgp-tools                           translate-shell
# hpack                                    translate-toolkit
# htmlcleaner                              transmission-cli
# http-server                              travis
# httpflow                                 treefrog
# httpie                                   trezor-agent
# hugo                                     triangle
# iam-policy-json-to-terraform             triton
# iblinter                                 tth
# igraph                                   tundra
# imagemagick@6                            tvnamer
# imgproxy                                 txr
# inform6                                  typescript
# inlets                                   uchardet
# inspircd                                 ucloud
# instead                                  uftp
# inxi                                     uhd
# ipfs                                     ultralist
# ipython                                  uncrustify
# ircd-hybrid                              ungit
# iso-codes                                unoconv
# ispc                                     unpaper
# istioctl                                 urdfdom
# janet                                    urdfdom_headers
# jansson                                  urh
# jbake                                    urweb
# jdupes                                   userspace-rcu
# jena                                     util-linux
# jenkins                                  uwsgi
# jenkins-job-builder                      v8
# jetty                                    vagrant-completion
# jetty-runner                             vala
# jflex                                    vale
# jfrog-cli-go                             vapoursynth
# jhipster                                 vapoursynth-imwri
# jlog                                     vapoursynth-ocr
# jmeter                                   vapoursynth-sub
# joplin                                   vault
# jrnl                                     vcs
# jrtplib                                  vdirsyncer
# jsonrpc-glib                             verilator
# juju                                     vert.x
# jupyterlab                               vfuse
# kapacitor                                vgmstream
# katago                                   vim
# keepassc                                 vips
# kerl                                     vit
# khal                                     vnu
# kibana                                   vpn-slice
# kind                                     vte3
# kitchen-sync                             vttest
# knot                                     vulkan-headers
# komposition                              wabt
# kops                                     wallpaper
# kpcli                                    wartremover
# ktoblzcheck                              wasm3
# kubecfg                                  watchman
# kubectx                                  wcslib
# kubeprod                                 weaver
# kubernetes-cli                           webarchiver
# kubernetes-service-catalog-client        weboob
# kubeseal                                 webpack
# kumo                                     webtorrent-cli
# kustomize                                weechat
# kvazaar                                  whatmp3
# kyma-cli                                 whistle
# languagetool                             widelands
# lasso                                    wildfly-as
# lazygit                                  wireguard-tools
# lcm                                      wireshark
# ledger                                   wolfmqtt
# lego                                     wolfssl
# lensfun                                  wordgrinder
# lerna                                    wpscan
# lft                                      wrangler
# libarchive                               write-good
# libav                                    wtf
# libcbor                                  wtfutil
# libcdr                                   wumpus
# libcec                                   wxmac
# libdap                                   wxmaxima
# libdazzle                                xa
# libdeflate                               xapian
# libexif                                  xclogparser
# libfabric                                xgboost
# libfido2                                 xmake
# libfreehand                              xml-tooling-c
# libgeotiff                               xmrig
# libgit2                                  xonsh
# libgit2-glib                             xrootd
# libgr                                    xtensor
# libgweather                              yaegi
# libhttpserver                            yapf
# libical                                  yaws
# libksba                                  yaz
# liblcf                                   yle-dl
# libmspub                                 yosys
# libmypaint                               yq
# libntlm                                  z
# libosmium                                z3
# libphonenumber                           zabbix
# libplctag                                zbackup
# libpq                                    zebra
# libpqxx                                  zeek
# libproxy                                 zero-install
# libpulsar                                zig
# libqalculate                             znc
# librdkafka                               zorba
# libressl                                 zstd
# ==> Deleted Formulae
# crc                        deisctl                    open-cobol
# deis                       gnome-builder              pijul
# ==> Updated Casks
# java ✔
# 0-ad
# 010-editor
# 115browser
# 1password
# 1password-cli
# 4k-stogram
# 4k-video-downloader
# 4k-youtube-to-mp3
# a-better-finder-attributes
# a-better-finder-rename
# ableton-live
# ableton-live-intro
# ableton-live-lite
# ableton-live-standard
# ableton-live-suite
# abricotine
# abstract
# acquia-dev
# activitywatch
# actual-odbc-pack
# adafruit-arduino
# adium
# adobe-acrobat-reader
# adoptopenjdk
# agenda
# air-video-server-hd
# aircall
# airdisplay
# airdroid
# airflow
# airpass
# airqmon
# airserver
# airtable
# airtame
# airy
# alephone
# alfaview
# aliworkbench
# all-in-one-messenger
# alt-tab
# altair-graphql-client
# altserver
# alva
# amadeus-pro
# amadine
# amazon-chime
# amazon-music
# amazon-photos
# amazon-workdocs
# amazon-workspaces
# amethyst
# amitv87-pip
# ananas-analytics-desktop-edition
# android-file-transfer
# android-ndk
# android-platform-tools
# android-sdk
# android-studio
# angry-ip-scanner
# anka-flow
# anki
# another-redis-desktop-manager
# anvil
# anydo
# anylist
# apache-couchdb
# apache-directory-studio
# apk-icon-editor
# app-tamer
# appcode
# appgate-sdp-client
# appium
# appstudio
# appzapper
# aptanastudio
# aptible
# aqua-data-studio
# aquamacs
# archiver
# aria-maestosa
# aria2d
# ariang
# ark-desktop-wallet
# armory
# arq
# arq-cloud-backup
# arrayfire
# arrsync
# artisan
# asciidocfx
# astah-professional
# astropad
# astropad-studio
# atext
# atom
# audio-hijack
# audioslicer
# audirvana
# auristor-client
# auryo
# authy
# autofirma
# autopkgr
# autumn
# avg-antivirus
# aviatrix-vpn-client
# avibrazil-rdm
# avidemux
# avira-antivirus
# avocode
# avogadro
# awa
# aware
# aws-vault
# axe-electrum
# axure-rp
# azure-data-studio
# back-in-time
# backblaze
# backlog
# backuploupe
# badlion-client
# baiducloud
# baidunetdisk
# balenaetcher
# ballast
# balsamiq-wireframes
# bandage
# bankid
# banking-4
# banktivity
# banshee
# baritone
# barxtemp
# base
# basecamp
# basictex
# bathyscaphe
# battlescribe
# bbc-iplayer-downloads
# bbedit
# bdash
# beaker-browser
# beatunes
# beautune
# bee
# beersmith
# bestres
# bettertouchtool
# betterzip
# betwixt
# bibdesk
# bilimini
# bino
# birdfont
# biscuit
# bisq
# bit-slicer
# bitmessage
# bitshares
# bitwarden
# blink1control
# blisk
# blitz
# blobby-volley2
# blockblock
# blockstack
# blocs
# blue-jeans
# bluefish
# bonitastudiocommunity
# bookmacster
# boom
# boom-3d
# boostnote
# bootstrap-studio
# bootxchanger
# borgbackup
# bossa
# bot-framework-emulator
# box-drive
# box-edit
# box-sync
# boxer
# brackets
# brain-workshop
# brave-browser
# breakaway
# breaktimer
# brewtarget
# bria
# bricklink-studio
# bricksmith
# brl-cad-mged
# brook
# btcpayserver-vault
# bubo
# buildsettingextractor
# bunch
# bunqcommunity-bunq
# burn
# burp-suite
# busycal
# busycontacts
# butt
# buttercup
# bzflag
# c0re100-qbittorrent
# cabal
# cacher
# cakebrew
# calcservice
# calendar-366
# calibre
# camed
# camtasia
# camunda-modeler
# canary
# caprine
# captain
# captin
# caption
# capto
# carbon-copy-cloner
# cardhop
# caret
# catch
# catlight
# cave-story
# ccmenu
# cctalk
# cellery
# cellprofiler
# cemu
# cerebro
# chalk
# chatmate-for-facebook
# chatmate-for-whatsapp
# chatology
# chatty
# cheatsheet
# checkra1n
# chemdoodle
# chessx
# chiaki
# chromedriver
# chromium
# chrysalis
# citra
# ckan
# clashx
# classroom-assistant
# clean-me
# cleanmymac
# clementine
# clion
# clip-studio-paint
# clipy
# clock
# clockify
# clonk
# cloud-pbx
# cloudapp
# cloudcompare
# cloudmounter
# clover-configurator
# cmake
# cncjs
# cncnet
# coccinellida
# cockatrice
# cocktail
# cocoapods
# cocoarestclient
# code-notes
# code42-crashplan
# codekit
# coderunner
# collabshot
# colorpicker-skalacolor
# colorsnapper
# colortester
# colour-contrast-analyser
# comma-chameleon
# commander-one
# commandq
# controllermate
# controlplane
# cookie
# copyclip
# copyq
# coqide
# cord
# corona-tracker
# coteditor
# couchbase-server-enterprise
# couchpotato
# coverload
# cozy-drive
# creepy
# cronnix
# cryptomator
# crystalmaker
# cubicsdr
# cuda-z
# cumulus
# cura-lulzbot
# cutbox
# cutter
# cyberduck
# cycling74-max
# cytoscape
# daedalus
# daemon-tools
# daily-english-listening
# darktable
# dash
# dash-dash
# dashcam-viewer
# dashlane
# dat
# data-science-studio
# datadog-agent
# datagrip
# datazenit
# datovka
# datweatherdoe
# davmail
# db-browser-for-sqlite
# dbeaver-community
# dbglass
# dbkoda
# dbngin
# dbschema
# dbvisualizer
# dcommander
# dcp-o-matic
# dcp-o-matic-batch-converter
# dcp-o-matic-encode-server
# dcp-o-matic-kdm-creator
# dcp-o-matic-player
# dcv-viewer
# dd-utility
# debookee
# deckset
# deco
# deeper
# deepstream
# deezer
# default-folder-x
# delicious-library
# deltawalker
# deluge
# detectx-swift
# detexify
# devdocs
# devolo-cockpit
# devonagent
# devonthink
# dexed
# dhs
# dia
# dialpad
# diashapes
# dictater
# dictionaries
# difffork
# digikam
# dingtalk
# disk-arbitrator
# disk-drill
# diskcatalogmaker
# displaycal
# dissenter-browser
# djay-pro
# djv
# djview
# do-not-disturb
# docker
# docker-toolbox
# dockstation
# dogecoin
# doly
# domainbrain
# dosbox
# dosbox-x
# doteditor
# dotnet
# dotnet-sdk
# double-commander
# downie
# doxygen
# dragthing
# drama
# drawbot
# drawio
# dremel-slicer
# drop-to-gif
# droplr
# dropshare
# duckietv
# duet
# dukto
# duo-connect
# dupeguru
# duplicacy
# duplicacy-web-edition
# duplicati
# dust3d
# dvdstyler
# dwarf-fortress-lmp
# dynamodb-local
# ebmac
# eddie
# edfbrowser
# editaro
# edrawmax
# elan
# elasticwolf
# electerm
# electric-sheep
# electron
# electron-fiddle
# electronmail
# electrumsv
# eloston-chromium
# emailchemy
# emby-server
# empoche
# encryptme
# endless-sky
# endurance
# engine-prime
# enpass
# entropy
# envkey
# epic
# epic-games
# epichrome
# epub-to-pdf
# eqmac
# espresso
# eudic
# eurkey
# everweb
# exactscan
# exfalso
# exist-db
# exodus
# expo-xde
# expressvpn
# extraterm
# falcon-sql-client
# family-tree-builder
# fanny
# fantastical
# fantasy-map-generator
# farrago
# favro
# fedora-media-writer
# feed-the-beast
# feem
# feishu
# fenix
# ferdi
# figtree
# fiji
# filedrop
# filepane
# find-any-file
# finicky
# firecamp
# firefox
# firestormos
# fl-studio
# flame
# flash-decompiler-trillix
# flash-npapi
# flash-player
# flash-player-debugger
# flash-player-debugger-npapi
# flash-player-debugger-ppapi
# flash-ppapi
# flashlighttool
# fldigi
# flic
# flightgear
# flipper
# flock
# flowdock
# flowsync
# flume
# fluor
# fly
# fman
# focus-booster
# focusatwill
# focused
# focuswriter
# folding-at-home
# foldingtext
# foldit
# fontbase
# fontexplorer-x-pro
# fontforge
# fontgoggles
# fontlab
# fontplop
# forecast
# fork
# forklift
# forticlient
# foxitreader
# fpcsrc
# framer
# franz
# freac
# fredm-fuse
# free-ruler
# freecad
# freecol
# freedom
# freemind
# freenettray
# freeorion
# freeplane
# freesmug-chromium
# freeyourmusic
# frescobaldi
# frhelper
# fromscratch
# front
# fs-uae
# fsmonitor
# fsnotes
# funter
# fuse
# futuniuniu
# fuwari
# ganache
# ganttproject
# garagebuy
# garagesale
# gb-studio
# gcollazo-mongodb
# gdlauncher
# gearboy
# gearsystem
# geektool
# gemini
# genymotion
# geogebra
# geotag-photos-pro
# geph
# gephi
# get-backup-pro
# getrasplex
# gfortran
# ghost
# ghost-browser
# ghosttile
# gifox
# gifs
# gingko
# gisto
# gitahead
# gitbox
# gitfinder
# gitfox
# github
# gitify
# gitkraken
# gitnote
# gitup
# gloomhaven-helper
# glyphfinder
# glyphs
# gmvault
# gns3
# gnucash
# go-agent
# go-server
# gobdokumente
# godot
# godot-mono
# gog-galaxy
# gogs
# goland
# goldencheetah
# goldendict
# golly
# goodsync
# goofy
# google-chrome
# google-earth-pro
# google-japanese-ime
# googleappengine
# gopass-ui
# gplates
# gpodder
# gpower
# gps4cam
# gpxsee
# gqrx
# gramps
# grandperspective
# grandtotal
# graphicconverter
# gretl
# gridea
# grids
# grisbi
# growlnotify
# gswitch
# gtkwave
# guijs
# guild-wars2
# gureumkim
# gzdoom
# ha-menu
# hacker-menu
# hackhands
# hackintool
# hammerspoon
# handbrake
# handshaker
# handylock
# haptic-touch-bar
# harmony
# haroopad
# harvest
# hazel
# hbuilder
# hbuilderx
# hdrmerge
# headset
# heimdall-suite
# helium
# hermes
# hex-fiend
# hipchat
# hma-pro-vpn
# houdahspot
# houseparty
# hstracker
# http-toolkit
# hubic
# hubstaff
# hugin
# hydrogen
# hyper
# hyperbackupexplorer
# ibackup-viewer
# ibettercharge
# ibm-cloud-cli
# icab
# icestudio
# iconizer
# iconjar
# icq
# idagio
# iexplorer
# igdm
# iglance
# image2icon
# imagej
# imaging-edge
# imazing-mini
# imgotv
# impactor
# indigo
# inkdrop
# inkscape
# inky
# insomnia
# inssider
# instant-articles-builder
# insync
# integrity
# intel-haxm
# intel-power-gadget
# intellij-idea
# intellij-idea-ce
# intelliscape-caffeine
# invesalius
# invisiblix
# inxmail-professional
# ionic-lab
# ios-app-signer
# iota-wallet
# ipe
# ipepresenter
# ipfs
# ipremoteutility
# ipsecuritas
# irccloud
# iridium
# iris
# ishowu-instant
# istat-server
# itch
# iterm2
# ithoughtsx
# itk-snap
# itools
# itsycal
# itubedownloader
# itunes-volume-control
# ivideonclient
# ivideonserver
# ivpn
# j
# jabref
# jalbum
# jalview
# jamf-migrator
# jami
# jamovi
# jasp
# jasper
# jaxx-liberty
# jbrowse
# jd-gui
# jdk-mission-control
# jedit
# jedit-omega
# jeromelebel-mongohub
# jet
# jetbrains-toolbox
# jgrasp
# jitsi-meet
# joplin
# journey
# jubler
# juicebar
# jump
# jumpcut
# jumpshare
# jupyter-notebook-viewer
# kactus
# kakapo
# kaku
# kaleidoscope
# kap
# kapow
# katalon-studio
# keep-it
# keepassxc
# keepingyouawake
# keeweb
# keka
# kext-updater
# kextviewr
# keybase
# keyboard-maestro
# keyboardcleantool
# keymanager
# keyshot
# keystore-explorer
# kicad
# kid3
# kindle
# kindle-comic-creator
# kindle-previewer
# kindlegen
# kinza
# kite
# kitematic
# kitty
# kiwi-for-g-suite
# kiwix
# klatexformula
# klayout
# klokki
# knime
# knock
# knockknock
# knotes
# knox
# knuff
# koa11y
# koala
# kobo
# kode54-cog
# kodelife
# kodi
# kotlin-native
# krisp
# krita
# kstars
# kube-forwarder
# kubernetic
# kugoumusic
# lando
# lantern
# laravel-kit
# lark
# lastpass
# latexdraw
# latexit
# launchcontrol
# laverna
# lazarus
# lazpaint
# lbry
# league-displays
# league-of-legends
# leanote
# ledger-live
# lego-mindstorms-ev3
# lehreroffice
# lektor
# lelivrescolairefr
# lens
# lepton
# librecad
# libreoffice
# libreoffice-language-pack
# liclipse
# lidarr
# lifesize
# lightgallery
# lightproxy
# lighttable
# lightworks
# lincastor
# line-bot-designer
# linear
# lingo
# lingon-x
# listen1
# liteide
# little-snitch
# lmms
# local
# localdev
# localizationeditor
# lockdown
# lockrattler
# logdna-agent
# logdna-cli
# loginputmac
# logisim
# logitech-presentation
# logmein-hamachi
# logos
# loom
# loopback
# losslesscut
# love
# lulu
# luminance-hdr
# lunar
# luxmark
# luyten
# lynkeos
# lynx
# lyricsx
# maccy
# macdjview
# macdown
# macgamestore
# macgdbp
# macpass
# macpilot
# macs-fan-control
# macsvg
# mactex
# mactex-no-gui
# mactracker
# macupdater
# macwinzipper
# macx-dvd-ripper-pro
# magicavoxel
# magiccap
# mailbutler
# mailmaster
# mailmate
# mailspring
# maintenance
# makehuman
# maltego
# malus
# malwarebytes
# mame
# manico
# manta
# manuscripts
# manuskript
# marathon
# marginnote
# mark-text
# marshallofsound-google-play-music-player
# marvel
# marvin
# masscode
# master-password
# masterway-note
# mate-translate
# mattermost
# mblock
# mcbopomofo
# mcedit
# media-converter
# mediaelch
# megahertz-knotes
# meld
# mellowplayer
# melodics
# memory
# memory-map
# mendeley-reference-manager
# menubar-countdown
# menumeters
# menutube
# merlin-project
# meshcommander
# meshlab
# metabase
# metasploit
# metaz
# meteorologist
# mgba
# mia-for-gmail
# michaelvillar-timer
# microblog
# microsoft-edge
# microsoft-excel
# microsoft-office
# microsoft-outlook
# microsoft-powerpoint
# microsoft-r-open
# microsoft-teams
# microsoft-word
# middleclick
# midikeys
# miditrail
# mikogo
# miktex-console
# milanote
# milkytracker
# mimecast
# min
# mindforger
# mindjet-mindmanager
# minecraft
# minecraft-server
# minecraftpe
# mini-program-studio
# miniconda
# minizincide
# miro-formerly-realtimeboard
# mirrordisplays
# mission-control-plus
# mjml
# mjolnir
# mkchromecast
# mkvtoolnix
# mmex
# mnemosyne
# mochi
# mockoon
# mockplus
# mockuuups-studio
# modelio
# moneywiz
# mongodb-compass
# mongodb-compass-community
# mongodb-compass-isolated-edition
# mongodb-compass-readonly
# mongotron
# monitorearth
# mono-mdk
# monogame
# monolingual
# moonlight
# morpheus
# mos
# moscow-ml
# motion
# motrix
# mountain-duck
# movist-pro
# mpeg-streamclip
# mplab-xc32
# mplayer-osx-extended
# mplayerx
# mps
# mpv
# mqtt-explorer
# mqttfx
# mtmr
# mu-editor
# mucommander
# mudlet
# mullvadvpn
# multifirefox
# multipass
# multitouch
# mumble
# munki
# murus
# museeks
# musescore
# music-manager
# musicbrainz-picard
# mweb
# my-budget
# my-image-garden
# mycloud
# mycrypto
# mylio
# mymonero
# mysqlworkbench
# nagbar
# nally
# namebench
# nano
# natron
# navicat-data-modeler
# navicat-data-modeler-essentials
# navicat-for-mariadb
# navicat-for-mysql
# navicat-for-oracle
# navicat-for-postgresql
# navicat-for-sql-server
# navicat-for-sqlite
# navicat-premium
# navicat-premium-essentials
# nbtexplorer
# ndm
# neo4j
# neofinder
# nestopia
# netdownloadhelpercoapp
# neteasemusic
# netiquette
# netnewswire
# netron
# netxms-console
# ngrok
# nheko
# night-owl
# nightingale
# nimble
# nisus-thesaurus
# nodebox
# nodeclipse
# noisytyper
# nomachine
# nordvpn
# nosleep
# nosql-workbench-for-amazon-dynamodb
# nosqlbooster-for-mongodb
# nosqlclient
# notable
# notedup
# noteplan
# noti
# notion
# noun-project
# now
# noxappplayer
# nrlquaker-winbox
# nsregextester
# nteract
# nuclear
# nucleo
# nuclino
# nulloy
# numi
# nvalt
# nvidia-geforce-now
# nzbget
# obs
# obyte
# ocenaudio
# oclint
# odio
# odrive
# ogdesign-eagle
# omegat
# omnidazzle
# omnifocus
# omnigraffle
# one-switch
# onedrive
# onenote-importer-preview
# oni
# onyx
# oolite
# open-ecard
# openarena
# openaudible
# openbazaar
# openboard
# openboardview
# openconnect-gui
# opencore-configurator
# openemu
# openmsx
# openmtp
# openmw
# opennx
# openoffice
# openra
# openrct2
# openrefine
# opensesame
# openshot-video-editor
# opensong
# opentoonz
# openvanilla
# openvisualtraceroute
# openwebstart
# openzfs
# opera
# optimal-layout
# oracle-jdk-javadoc
# origami-studio
# origin
# orka
# oryoki
# oscar
# osxfuse
# otter-browser
# outline
# outline-manager
# overflow
# oversight
# owasp-zap
# p4v
# pacifist
# packages
# packet-peeper
# packetproxy
# packetsender
# pagico
# paintbrush
# paintcode
# pandora
# panoply
# paperspace
# parallels
# parallels-toolbox
# parse
# parsec
# particle-dev
# password-gorilla
# pastebot
# path-finder
# pd-l2ork
# pdf-converter-master
# pdf-expert
# pdf-toolbox
# pdfelement
# pdfpen
# pdfpenpro
# pdfsam-basic
# penc
# pencil2d
# perforce
# permute
# persepolis-download-manager
# pext
# pg-commander
# pgadmin4
# phantomjs
# phoenix-slides
# phonegap
# photoninja
# photosweeper-x
# phpstorm
# pibakery
# piezo
# pineapple
# pinegrow
# pingid
# pingplotter
# pinta
# pixelsnap
# plan
# play
# playback
# playmemories-home
# plex
# plex-media-player
# plex-media-server
# plexamp
# pliim
# plotdigitizer
# plover
# pocket-casts
# podolski
# poedit
# poi
# pokerth
# polar-bookshelf
# polymail
# pomotodo
# pomotroid
# popchar
# popo
# portfolioperformance
# porting-kit
# postbox
# posterazor
# postgres
# postico
# postman
# powder-player
# powerpanel
# powerphotos
# powershell
# praat
# preform
# prepros
# presentation
# principle
# prismatik
# pritunl
# private-internet-access
# privatetunnel
# proclaim
# projectlibre
# propresenter
# protege
# protonmail-bridge
# protopie
# provisionql
# proximity
# proxyman
# prudent
# prusaslicer
# psi
# psi-plus
# publish-or-perish
# pulse-sms
# puppetry
# purevpn
# pycharm
# pycharm-ce
# pycharm-ce-with-anaconda-plugin
# pycharm-edu
# pycharm-with-anaconda-plugin
# pyfa
# pynsource
# pyzo
# qbittorrent
# qblocker
# qcma
# qdslrdashboard
# qgis
# qgroundcontrol
# qiyimedia
# qlab
# qlfits
# qlstephen
# qnapi
# qobuz
# qownnotes
# qq
# qsync-client
# qt-creator
# qtox
# qtpass
# qtspim
# quakespasm
# quassel
# querious
# quickbooks-online
# quicken
# quip
# quiterss
# quodlibet
# qutebrowser
# qv2ray
# qxmledit
# r
# rabbitmq
# race-into-space
# racket
# racket-cs
# radarr
# radiant-player
# rambox
# ransomwhere
# rapidweaver
# raven
# razorsql
# rclone-browser
# rcloneosx
# react-native-debugger
# react-proto
# react-studio
# reaper
# rectangle
# redis
# refined-github-safari
# reggy
# reikey
# remember-the-milk
# remote-desktop-manager
# remote-desktop-manager-free
# remoteviewer
# remotix-agent
# renamer
# resilio-sync
# resolume-arena
# retinizer
# retro-virtual-machine
# retroarch
# retroarch-metal
# retroshare
# reunion
# reveal
# rhinoceros
# ricochet
# rider
# ridibooks
# ring
# ringcentral
# riot
# ripcord
# roaringapps
# robofont
# roboform
# rocket
# rocket-chat
# rodeo
# rotato
# routebuddy
# rowanj-gitx
# rowmote-helper
# royal-tsx
# rssowl
# rstudio
# rsyncosx
# rubymine
# runjs
# runway
# ryver
# sabaki
# sabnzbd
# sage
# sameboy
# saoimageds9
# sapmachine-jdk
# satellite-eyes
# sauerbraten
# scala-ide
# scaleft
# scap-workbench
# scapple
# schism-tracker
# scidavis
# scidvsmac
# scihubeva
# scilab
# scope
# scout
# scratch
# screen
# screenflick
# screens
# screens-connect
# scribus
# script-debugger
# scrivener
# scrutiny
# seadrive
# seafile-client
# seaglass
# seamonkey
# seashore
# second-life-viewer
# segger-embedded-studio-for-arm
# sejda-pdf
# selfcontrol
# sencha
# send-to-kindle
# sensei
# sensiblesidebuttons
# sequel-pro
# serviio
# session
# session-manager-plugin
# setapp
# sharepod
# shift
# shifty
# shimo
# shoes
# shotcut
# showyedge
# shuttle
# sidequest
# sidestep
# sigil
# signal
# silentknight
# simple-comic
# simplenote
# simplesynth
# simply-fortran
# singularity
# sirimote
# sizzy
# skala-preview
# sketch
# sketchpacks
# sketchup
# sketchup-pro
# skim
# skreenics
# skyfonts
# skype
# skype-for-business
# slack
# slate
# slicer
# slimbatterymonitor
# slingplayer
# slite
# smartgit
# smlnj
# smooze
# snagit
# sneek
# snes9x
# snipaste
# snowflake-snowsql
# soapui
# socket-io-tester
# softmaker-freeoffice
# softorino-youtube-converter
# softraid
# softube-central
# sogouinput
# solvespace
# sonic-visualiser
# soulver
# sound-control
# sound-siphon
# soundcleod
# sourcetrail
# sourcetree
# sparkle
# sparkleshare
# spectacle
# spectacle-editor
# spectrum
# spectx
# speedcrunch
# spek
# spillo
# spires
# splashtop-business
# splashtop-personal
# splashtop-streamer
# splice
# spotifree
# spotify
# spotspot
# springtoolsuite
# sql-tabs
# sqlectron
# sqlexplorer
# sqlpro-for-mssql
# sqlpro-for-mysql
# sqlpro-for-postgres
# sqlpro-for-sqlite
# sqlpro-studio
# squirrel
# squirrelsql
# ssh-tunnel-manager
# stack
# stand
# standard-notes
# starcraft
# startninja
# startupizer
# station
# stay
# steam
# steamcmd
# steermouse
# stella
# stellarium
# stepmania
# stoplight-studio
# storyboarder
# strawberry
# stretchly
# strongvpn
# studio-3t
# studiolinkstandalone
# subler
# sublime-merge
# subsurface
# sunvox
# supercollider
# superduper
# superproductivity
# supertuxkart
# surge
# surge-synthesizer
# sweet-home3d
# swift-explorer
# swift-publisher
# swiftformat-for-xcode
# swiftstack-client
# swifty
# swiftybeaver
# swinsian
# swish
# switchhosts
# switchresx
# synalyze-it-pro
# sync-my-l2p
# syncovery
# syncplay
# syncterm
# syncthing
# synfigstudio
# synthesia
# sysdig-inspect
# tableau
# tableau-prep
# tableau-public
# tableau-reader
# tableflip
# tableplus
# tabula
# tad
# tagger
# tagspaces
# tandem
# taskade
# taskexplorer
# tastyworks
# tbe
# tbs-studio
# tcl
# td-agent
# teambition
# teamdrive
# teamspeak-client
# teamviewer
# teamwire
# teeworlds
# telavox-flow
# telegram
# telegram-desktop
# tempo
# tencent-lemon
# tenor
# termhere
# terminus
# termius
# texpad
# texstudio
# textadept
# textexpander
# textmate
# texworks
# the-archive-browser
# the-battle-for-wesnoth
# the-cheat
# the-unarchiver
# thebrain
# thedesk
# there
# therm
# thingsmacsandboxhelper
# thonny
# thonny-xxl
# thor
# threads
# thumbsup
# thunder
# thunderbird
# thyme
# tibco-jaspersoft-studio
# tickeys
# ticktick
# tiddly
# tidepool-uploader
# tifig
# tiger-trade
# tigervnc-viewer
# tikzit
# tiled
# tiles
# timecamp
# timelane
# timely
# timemator
# timestamp
# timeular
# timing
# tinderbox
# tinkerwell
# tiny-player
# tinymediamanager
# tinypng4mac
# tla-plus-toolbox
# todometer
# todotxt
# toggl
# toontown-rewritten
# toptracker
# tor-browser
# torguard
# torrent-file-editor
# tortoisehg
# touchdesigner
# tower
# townwifi
# trader-workstation
# trailer
# trainerroad
# transmission
# transmit
# transocks
# transtype
# tresorit
# trezor-bridge
# tribler
# trilium-notes
# trim-enabler
# trinity
# triplecheese
# trolcommander
# tropy
# trufont
# tunnelbear
# tunnelblick
# tuntap
# tuple
# turbo-boost-switcher
# turbovnc-viewer
# turtl
# tusk
# tuxguitar
# tv-browser
# tvrenamer
# tweetbot
# tweeten
# twine
# twist
# twitch
# typora
# tysimulator
# ubar
# uberconference
# ubersicht
# uc-one
# udig
# ueli
# ultimaker-cura
# ultimate
# ultrastardeluxe
# uncolored
# understand
# unetbootin
# unicodechecker
# uniconverter
# unison
# unite
# unity
# unity-android-support-for-editor
# unity-download-assistant
# unity-ios-support-for-editor
# unity-lumin-support-for-editor
# unity-webgl-support-for-editor
# unity-windows-support-for-editor
# universal-media-server
# unpkg
# upic
# upm
# upwork
# utools
# utox
# uu-booster
# vagrant
# vagrant-manager
# vagrant-vmware-utility
# vassal
# vellum
# veracrypt
# veusz
# vidcutter
# videostream
# vidrio
# vienna
# vimr
# vip-access
# virtualbox
# virtualbox-extension-pack
# virtualgl
# virtualhostx
# visicut
# visit
# visual
# visual-paradigm
# visual-paradigm-ce
# visual-studio
# visual-studio-code
# visualboyadvance-m
# visualvm
# vitalsource-bookshelf
# vitamin-r
# vivaldi
# vivi
# vk-messenger
# vlc
# vmpk
# vnote
# volt
# voodoopad
# vox
# vox-preferences-pane
# vscodium
# vsee
# vu
# vv
# vysor
# wacom-inkspace
# wallpaper-wizard
# waltr
# wanna
# wasabi-wallet
# waterfox
# waterfox-current
# wavebox
# wavesurfer
# webarchiveextractor
# webcamoid
# webcatalog
# webponize
# webpquicklook
# website-watchman
# webstorm
# webtorrent
# wechat
# wechatwork
# weiyun
# weka
# wercker-cli
# wey
# whalebird
# whatsapp
# whatsize
# whatsyoursign
# whoozle-android-file-transfer
# wickrme
# widelands
# wifispoof
# winds
# wings3d
# wire
# wireshark
# wireshark-chmodbpf
# wiznote
# wkhtmltopdf
# wondershare-filmora
# wordpresscom
# wordservice
# workflowy
# wpsoffice
# writefull
# wwdc
# x-moto
# x48
# xamarin-android
# xamarin-ios
# xamarin-mac
# xamarin-studio
# xamarin-workbooks
# xampp
# xaos
# xca
# xctu
# xdm
# xee
# xiami
# ximalaya
# xld
# xlink-kai
# xlplayer
# xmind-zen
# xquartz
# xrg
# xscope
# yacreader
# yakyak
# yammer
# yandex
# yandex-cloud-cli
# yandex-disk
# yate
# yed
# yinxiangbiji
# yojimbo
# youdaodict
# youdaonote
# youku
# yourkit-java-profiler
# yu-writer
# yy
# yyets
# zalo
# zappy
# zazu
# zeebe-modeler
# zeplin
# zeronet
# zesarux
# zettelkasten
# zettlr
# zoc
# zoho-docs
# zoho-mail
# zoho-workdrive
# zoom-in
# zoomus
# zotero
# zulip
# zxpinstaller
# ==> Deleted Casks
# appearin                                 livechat
# baiduhi                                  logoist
# capture-one                              madruby
# cloudtv                                  mammon
# cube                                     moodo
# dawnlabs-alchemy                         people-plus-content-ip
# deploystudio                             qtum-qt
# eve                                      roblox
# fastlane                                 safaricookiecutter
# feeder                                   safarisort
# glip                                     shinhan-ezplus
# gpsdump                                  sus-inspector
# grip                                     tftpserver
# hab                                      the-hit-list
# haskell-for-mac                          unity-linux-support-for-editor
# hider                                    validator-sac
# hook                                     whatsapp-pocket
# hyperion-download-manager                wineskin-winery
# iphoney                                  wko
# liteswitch-x
# ==> Downloading https://homebrew.bintray.com/bottles/jpeg-9d.mojave.bottle.tar.g
# ==> Downloading from https://akamai.bintray.com/b9/b931e7725c83275c56f962b51b83c
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/libtiff-4.1.0.mojave.bottle
# ==> Downloading from https://akamai.bintray.com/dd/dd060521aa30fb2f4678c9ebab636
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/ghostscript-9.52.mojave.bot
# ==> Downloading from https://akamai.bintray.com/89/8906a4dbf2513963a4710f351e342
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/libde265-1.0.5.mojave.bottl
# ==> Downloading from https://akamai.bintray.com/f0/f0b536c23ac8080dd7946dd3bcbe2
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/gettext-0.20.2_1.mojave.bot
# ==> Downloading from https://akamai.bintray.com/52/52067198cab528f05fdc0b06f7b97
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/libffi-3.3.mojave.bottle.ta
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/pcre-8.44.mojave.bottle.tar
# ==> Downloading from https://akamai.bintray.com/ed/ed9b483538da7bc6559d2e63dd366
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/openssl%401.1-1.1.1g.mojave
# ==> Downloading from https://akamai.bintray.com/5c/5c9d113393ff3efc95e5509175305
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/readline-8.0.4.mojave.bottl
# ==> Downloading from https://akamai.bintray.com/29/29f7102a730ab39c8312cad1e7e43
